# %% [markdown]
# # Quesiton 1 Explain the theoretical Simple Linear Regression model in your own words
#
# In a theoretical Simple Linear Regression (SLR) model, we aim to explain or predict the outcome variable, 𝑌 , using a predictor variable, 𝑋 . The model assumes a linear relationship between 𝑋  and 𝑌
#
# Y=β0 ​ +β1 ​ X+ε where:
#
# Y is the outcome (or dependent) variable.
#
# X is the predictor (or independent) variable.
#
# β 0 ​ is the intercept, representing the value of Y when 𝑋 = 0 .
#
# 𝛽 1 ​ is the slope, indicating the change in Y for a one-unit increase in X.
#
#  ε is the error term, which accounts for the variation in Y not explained by X.
#
#  #### consider the following code to better help understand

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the SLR model
beta_0 = 5       # Intercept
beta_1 = 2       # Slope
sigma = 3        # Standard deviation of the error term

# Generating a sample of predictor variable X
np.random.seed(0)
n = 100          # Number of observations
X = np.random.uniform(0, 10, n)

# Generating the outcome variable Y based on the model Y = beta_0 + beta_1 * X + epsilon
epsilon = np.random.normal(0, sigma, n)
Y = beta_0 + beta_1 * X + epsilon

# Plotting the data and the theoretical regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, Y, color='blue', alpha=0.6, label="Sample Data")
plt.plot(X, beta_0 + beta_1 * X, color='red', label="True Regression Line")

# Show normal distributions of Y around the regression line for a few X values
X_values = [2, 5, 8]  # Chosen X values to illustrate distributions
for x_val in X_values:
    y_mean = beta_0 + beta_1 * x_val
    y_distribution = norm(loc=y_mean, scale=sigma)
    y_range = np.linspace(y_mean - 3*sigma, y_mean + 3*sigma, 100)
    plt.plot([x_val]*100, y_range, 'k--', alpha=0.6)  # Vertical line at X
    plt.plot(x_val, y_mean, 'ro')  # Mean of Y for chosen X value
    plt.fill_betweenx(y_range, x_val - 0.2, x_val + 0.2, alpha=0.2, color='gray')
    plt.text(x_val, y_mean + 1, f"$N({y_mean:.1f}, {sigma**2})$", ha='center')

# Labels and legend
plt.xlabel("Predictor Variable X")
plt.ylabel("Outcome Variable Y")
plt.legend()
plt.title("Simple Linear Regression Model with Normal Distributions of Y at Selected X Values")
plt.show()

# %% [markdown]
# This visualization helps illustrate how each point of
# 𝑌 is theoretically sampled from a normal distribution centered around the regression line for a given
# 𝑋.

# %% [markdown]
# # Question 2 visualize a fitted Simple Linear Regression model using pandas and import statsmodels.formula.api as smf

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# Parameters for the theoretical Simple Linear Regression model
beta_0 = 5        # Intercept
beta_1 = 2        # Slope
sigma = 3         # Standard deviation of the error term

# Simulating the dataset
np.random.seed(0)
n = 100          # Number of observations
X = np.random.uniform(0, 10, n)  # Predictor variable
epsilon = np.random.normal(0, sigma, n)  # Error term
Y = beta_0 + beta_1 * X + epsilon  # Outcome variable

# Creating a DataFrame
data = pd.DataFrame({'X': X, 'Y': Y})

# Fit a Simple Linear Regression model using statsmodels
model = smf.ols(formula='Y ~ X', data=data)
results = model.fit()

# Print the summary of the model
print(results.summary())

# Visualizing the data and the fitted line
plt.figure(figsize=(10, 6))
plt.scatter(data['X'], data['Y'], color='blue', alpha=0.6, label="Simulated Data")
plt.plot(data['X'], beta_0 + beta_1 * data['X'], color='red', linestyle='--', label="True Line")
plt.plot(data['X'], results.fittedvalues, color='green', label="Fitted Regression Line")

# Labels and legend
plt.xlabel("Predictor Variable X")
plt.ylabel("Outcome Variable Y")
plt.legend()
plt.title("Fitted Simple Linear Regression Model")
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     357.9
# Date:                Tue, 29 Oct 2024   Prob (F-statistic):           1.74e-34
# Time:                        17:11:13   Log-Likelihood:                -251.38
# No. Observations:                 100   AIC:                             506.8
# Df Residuals:                      98   BIC:                             512.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.6665      0.580      9.772      0.000       4.516       6.817
# ...

# %% [markdown]
# # Question 3 Add the line from Question 1 on the figure of Question 2 and explain the difference between the nature of the two lines

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# Parameters for the theoretical Simple Linear Regression model
beta_0 = 5        # Intercept (True value)
beta_1 = 2        # Slope (True value)
sigma = 3         # Standard deviation of the error term

# Simulating the dataset
np.random.seed(0)
n = 100          # Number of observations
X = np.random.uniform(0, 10, n)  # Predictor variable
epsilon = np.random.normal(0, sigma, n)  # Error term
Y = beta_0 + beta_1 * X + epsilon  # Outcome variable

# Creating a DataFrame
data = pd.DataFrame({'X': X, 'Y': Y})

# Fit a Simple Linear Regression model using statsmodels
model = smf.ols(formula='Y ~ X', data=data)
results = model.fit()

# Print the summary of the model
print(results.summary())

# Visualizing the data, theoretical line, and fitted line
plt.figure(figsize=(10, 6))
plt.scatter(data['X'], data['Y'], color='blue', alpha=0.6, label="Simulated Data")

# Adding the true line from the theoretical model
x_range = np.array([data['X'].min(), data['X'].max()])
y_line = beta_0 + beta_1 * x_range
plt.plot(x_range, y_line, linestyle=':', color='orange', label=f"True Line: {beta_0} + {beta_1}*X")

# Adding the fitted regression line
plt.plot(data['X'], results.fittedvalues, color='green', label="Fitted Regression Line")

# Labels and legend
plt.xlabel("Predictor Variable X")
plt.ylabel("Outcome Variable Y")
plt.legend()
plt.title("Comparing Theoretical and Fitted Lines in Simple Linear Regression")
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     357.9
# Date:                Tue, 29 Oct 2024   Prob (F-statistic):           1.74e-34
# Time:                        17:37:35   Log-Likelihood:                -251.38
# No. Observations:                 100   AIC:                             506.8
# Df Residuals:                      98   BIC:                             512.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.6665      0.580      9.772      0.000       4.516       6.817
# ...

# %% [markdown]
# Theoretical (True) Line (orange dotted line): This line represents the exact relationship 𝑌 = 𝛽 0 + 𝛽 1 𝑋 + e, based on the true model parameters. Since this line is based on predefined parameters (not fitted from data), it stays constant across different simulations.
#
# Fitted Regression Line (green line): This line is obtained by fitting a Simple Linear Regression model to the simulated data. It represents the estimated relationship based on the specific sample data we generated.Due to random sampling variation in each simulation (caused by the random error term
# 𝜀), the fitted line will generally differ slightly from the true line, even though it approximates the same relationship. Each simulation will have its own unique fitted line due to variations in the sample data.

# %% [markdown]
# # Question 4 Explain how fitted_model.fittedvalues are derived on the basis of fitted_model.summary().tables[1]
#
# Illustration of How fitted_model.fittedvalues are Computed
# Let's manually calculate the predicted values using fitted_model.params for a clearer illustration:

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf

# Parameters for the theoretical Simple Linear Regression model
beta_0 = 5        # Intercept (True value)
beta_1 = 2        # Slope (True value)
sigma = 3         # Standard deviation of the error term

# Simulating the dataset
np.random.seed(0)
n = 100          # Number of observations
X = np.random.uniform(0, 10, n)  # Predictor variable
epsilon = np.random.normal(0, sigma, n)  # Error term
Y = beta_0 + beta_1 * X + epsilon  # Outcome variable

# Creating a DataFrame
data = pd.DataFrame({'X': X, 'Y': Y})

# Fit a Simple Linear Regression model using statsmodels
fitted_model = smf.ols(formula='Y ~ X', data=data).fit()

# Print the summary of the model to see fitted coefficients
print(fitted_model.summary())

# Extracting the estimated coefficients
intercept = fitted_model.params['Intercept']
slope = fitted_model.params['X']

# Manually calculating the fitted values using the estimated parameters
data['predicted_Y'] = intercept + slope * data['X']

# Comparing the manually calculated predictions with fitted_model.fittedvalues
print("First 5 Manual Predictions:", data['predicted_Y'].head())
print("First 5 fitted_model.fittedvalues:", fitted_model.fittedvalues.head())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     357.9
# Date:                Tue, 29 Oct 2024   Prob (F-statistic):           1.74e-34
# Time:                        18:16:50   Log-Likelihood:                -251.38
# No. Observations:                 100   AIC:                             506.8
# Df Residuals:                      98   BIC:                             512.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.6665      0.580      9.772      0.000       4.516       6.817
# ...

# %% [markdown]
# ### Derivation of fitted_model.fittedvalues The fitted_model.fittedvalues represents the "in-sample predictions" or predicted 𝑌-values for each observed 𝑋 in the dataset, based on the estimated model.
#
# In summary: The theoretical model uses known parameters ( 𝛽 0  and 𝛽 1  ​ ) to predict 𝑌 . The fitted model uses estimated parameters ( 𝛽^ 0  and 𝛽^ 1 ) to predict 𝑌 based on the actual sample data, yielding fitted_model.fittedvalues.

# %% [markdown]
# # Question 5
# In a fitted model using the "ordinary least squares" (OLS) method, the line is chosen to minimize the sum of the squared differences (or residuals) between observed data points and the line itself. This line is the one that most closely approximates the relationship between the predictor and outcome variables in the observed data.

# %% [markdown]
# # Question 6
#
# ## 1
# This expression defines 𝑅^2 by comparing the residual sum of squares (RSS),  ∑(Y−fitted_model.fittedvalues)^ 2 , with the total sum of squares (TSS),  ∑(Y−Y.mean)^2 . The term  ∑(Y−fitted_model.fittedvalues)^ 2 represents the unexplained variation by the model, while   ∑(Y−Y.mean)^ 2 represents the total variation in 𝑌  around its mean. Thus, 𝑅^2 can be interpreted as the proportion of variation in 𝑌  that is explained by the model's predictions. A higher 𝑅^2 implies that the model's fitted values closely track 𝑌 actual values, reflecting a better fit.
#
#
# ## 2
# fitted_model.rsquared: This attribute directly provides 𝑅 2  from the model, calculated using the same formula above. It’s a standardized measure of how well the predictor 𝑋  explains the variability in 𝑌 .
# ## 3
# np.corrcoef(Y, fitted_model.fittedvalues)[0, 1]**2: In Simple Linear Regression, 𝑅 2  is also the square of the correlation coefficient between 𝑌  and the predicted values 𝑌^  (i.e., fitted_model.fittedvalues). The correlation coefficient, calculated here with np.corrcoef, measures the linear relationship between 𝑌  and its predictions, and squaring it yields the proportion of variance explained, again equivalent to 𝑅^2   .
# ## 4
# np.corrcoef(Y, X)[0, 1]**2: In Simple Linear Regression, where there is only one predictor 𝑋 , 𝑅^2 is also equal to the square of the correlation coefficient between 𝑌  and 𝑋 . This captures the proportion of variance in  Y that is linearly explained by 𝑋  alone.

# %% [markdown]
# # Question 7
#
# 1. Linearity of the Relationship Between
# X and
# 𝑌
# Assumption: The model assumes a linear relationship between the predictor (fertilizer amount) and the outcome (crop yield), meaning that changes in
# 𝑋 should consistently relate to changes in
# 𝑌 through a straight-line relationship.
# Incompatibility with Data: The scatter plot likely shows a non-linear relationship, where crop yield initially increases with fertilizer use but at different rates, suggesting that a straight line may not fit the data well. This non-linear pattern could mean that a different model, such as a quadratic or exponential model, might be more appropriate.
#
# 2. Normality of the Residuals
# Assumption: The residuals (the differences between observed and predicted
# 𝑌-values) should follow a normal distribution, with no systematic patterns. This is important for making reliable predictions and inferences from the model.
# Incompatibility with Data: The histogram of residuals may show a skewed or multi-modal distribution rather than a normal bell curve, indicating that the residuals do not satisfy the normality assumption. This could be due to the non-linear relationship mentioned above or to outliers that strongly affect the residuals.

# %% [markdown]
# # Question 8
#  Null Hypothesis Specification For a Simple Linear Regression model of the form: 𝑌 = 𝛽 0 + 𝛽 1 𝑋 + 𝜖  where 𝑌  represents the eruption duration and 𝑋 X represents the waiting time, we specify the null and alternative hypotheses as follows: Null Hypothesis ( 𝐻 0 ): There is no linear association between waiting time and eruption duration, which implies that the slope parameter 𝛽 1 = 0. Alternative Hypothesis ( 𝐻 1  ): There is a linear association between waiting time and eruption duration, implying 𝛽 1 ≠ 0
#
# If the p-value for 𝛽 1  is low, we would reject the null hypothesis and conclude there is evidence of a significant linear association between waiting time and eruption duration. Conversely, if the p-value is high, we would fail to reject the null hypothesis, suggesting insufficient evidence for a linear relationship. This p-value-based interpretation allows us to determine if the observed association is likely due to chance or reflects a genuine relationship in the population.

# %% [markdown]
# # Question 9
# For each short wait limit, our hypotheses are as follows: Null Hypothesis ( 𝐻 0  ): There is no linear relationship between wait time and eruption duration for short wait times, meaning the slope 𝛽 1 = 0 . Alternative Hypothesis ( 𝐻 1): There is a linear relationship between wait time and eruption duration for short wait times, implying 𝛽 1 ≠ 0.

# %%
import seaborn as sns
import plotly.express as px
import statsmodels.formula.api as smf

# Load the Old Faithful Geyser dataset
old_faithful = sns.load_dataset('geyser')

# Define short wait limits
short_wait_limits = [62, 64, 66]

for short_wait_limit in short_wait_limits:
    short_wait = old_faithful['waiting'] < short_wait_limit
    model = smf.ols('duration ~ waiting', data=old_faithful[short_wait]).fit()
    
    # Display the coefficient table
    print(f"Short wait limit: {short_wait_limit}")
    print(model.summary().tables[1])
    
    # Create and display the scatter plot with linear trendline
    fig = px.scatter(old_faithful[short_wait], x='waiting', y='duration', 
                     title=f"Old Faithful Geyser Eruptions for Short Wait Times (<{short_wait_limit})", 
                     trendline='ols')
    fig.show(renderer="png")
# Out:
# Short wait limit: 62
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6401      0.309      5.306      0.000       1.025       2.255
# waiting        0.0069      0.006      1.188      0.238      -0.005       0.019
# ...
# Short wait limit: 64
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4140      0.288      4.915      0.000       0.842       1.986
# waiting        0.0114      0.005      2.127      0.036       0.001       0.022
# ...
# Short wait limit: 66
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8619      0.327      2.637      0.010       0.213       1.511
# ...

# %% [markdown]
# for Each Short Wait Limit Using the p-value associated with the slope 𝛽 1 ​ , we interpret the results for each threshold: High p-value (e.g., > 0.05 ): We fail to reject 𝐻 0  , suggesting insufficient evidence of a linear relationship within the restricted dataset. This would imply that within these shorter wait times, duration is not significantly predicted by wait time. Low p-value (e.g., ≤ 0.05): We reject 𝐻 0  , indicating a significant linear relationship, meaning that even within shorter wait times, eruption duration may be predicted by wait time.

# %% [markdown]
# # Question 10
# # 10a)

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# Load the Old Faithful Geyser dataset
old_faithful = sns.load_dataset('geyser')

# Step 1: Filter for long wait times and take a sample of n=160
long_wait = old_faithful[old_faithful['waiting'] >= 70]
long_wait_sample = long_wait.sample(n=160, random_state=42)

# Bootstrap analysis
n_bootstrap = 1000
bootstrap_slopes = []

for _ in range(n_bootstrap):
    # Resample with replacement
    bootstrap_sample = long_wait_sample.sample(n=len(long_wait_sample), replace=True)
    
    # Fit the model to the bootstrap sample
    model = smf.ols('duration ~ waiting', data=bootstrap_sample).fit()
    
    # Collect the slope coefficient
    bootstrap_slopes.append(model.params['waiting'])

# Visualize the bootstrapped sampling distribution of slope coefficients
plt.figure(figsize=(10, 6))
plt.hist(bootstrap_slopes, bins=30, edgecolor='k', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Slope = 0')
plt.title('Bootstrapped Sampling Distribution of Slope Coefficient')
plt.xlabel('Slope Coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# We perform 1000 bootstrap samples with replacement from the long wait data subset.
# For each bootstrap sample, we fit a linear regression model and collect the slope coefficient.
# The histogram shows the distribution of these bootstrapped slope coefficients.

# %% [markdown]
# # 10b)

# %%
from scipy.stats import norm

# Parameters for the null hypothesis simulation
B0 = 1.65  # Intercept
B1 = 0     # Null hypothesis slope
sigma = 0.37  # Standard deviation of residuals
n_simulations = 1000
simulated_slopes = []

# Simulate sampling distribution under null hypothesis
for _ in range(n_simulations):
    # Generate simulated duration values assuming B1 = 0
    waiting_times = long_wait_sample['waiting'].values
    simulated_duration = B0 + B1 * waiting_times + norm.rvs(scale=sigma, size=len(waiting_times))
    
    # Create a DataFrame for the simulated sample
    simulated_sample = pd.DataFrame({'waiting': waiting_times, 'duration': simulated_duration})
    
    # Fit the model to the simulated sample
    sim_model = smf.ols('duration ~ waiting', data=simulated_sample).fit()
    
    # Collect the slope coefficient
    simulated_slopes.append(sim_model.params['waiting'])

# Visualize the simulated sampling distribution of the slope coefficient
plt.figure(figsize=(10, 6))
plt.hist(simulated_slopes, bins=30, edgecolor='k', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Slope = 0')
plt.title('Simulated Sampling Distribution of Slope Coefficient (Null Hypothesis)')
plt.xlabel('Slope Coefficient')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# We simulate samples from a Simple Linear Regression model under the null hypothesis where 𝛽 0 = 1.65 , 𝛽 1 = 0 , and 𝜎 = 0.37

# %% [markdown]
# # 10c)

# %%
# Calculate the 95% confidence interval from bootstrapped slopes
ci_lower, ci_upper = np.percentile(bootstrap_slopes, [2.5, 97.5])
print(f"95% Bootstrapped Confidence Interval for slope: ({ci_lower:.4f}, {ci_upper:.4f})")

# Fit the model on the actual long wait sample to get the observed slope and p-value
fitted_model = smf.ols('duration ~ waiting', data=long_wait_sample).fit()
observed_slope = fitted_model.params['waiting']
actual_p_value = fitted_model.pvalues['waiting']
print(f"Observed slope from the actual data: {observed_slope:.4f}")
print(f"Actual p-value from the fitted model: {actual_p_value:.4f}")

# Calculate the simulated p-value under the null hypothesis
simulated_p_value = np.mean([abs(slope) >= abs(observed_slope) for slope in simulated_slopes])
print(f"Simulated p-value under null hypothesis: {simulated_p_value:.4f}")

# Report if 0 is within the confidence interval
if ci_lower <= 0 <= ci_upper:
    print("0 is contained within the 95% bootstrapped confidence interval, so we fail to reject the null hypothesis.")
else:
    print("0 is NOT contained within the 95% bootstrapped confidence interval, so we have evidence against the null hypothesis.")
# Out:
# 95% Bootstrapped Confidence Interval for slope: (0.0089, 0.0332)
# Observed slope from the actual data: 0.0207
# Actual p-value from the fitted model: 0.0005
# Simulated p-value under null hypothesis: 0.0000
# 0 is NOT contained within the 95% bootstrapped confidence interval, so we have evidence against the null hypothesis.

# %% [markdown]
# # Question 11
# ### New Model Specification:
# We will create a Simple Linear Regression model using an indicator variable (binary variable) for the wait time length. Specifically, we define: A new binary variable  𝑘 𝑖 = 0 if the wait time is short (less than 68 minutes). 𝑘 𝑖 = 1  if the wait time is long (68 minutes or more).

# %%
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np
import pandas as pd

# Load the dataset
old_faithful = sns.load_dataset('geyser')

# Create the indicator variable for short and long wait times
old_faithful['kind'] = np.where(old_faithful['waiting'] < 68, 0, 1)

# Fit the model with the indicator variable
indicator_model = smf.ols('duration ~ waiting + kind', data=old_faithful).fit()

# Display the summary of the fitted model
print(indicator_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               duration   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.886
# Method:                 Least Squares   F-statistic:                     1052.
# Date:                Fri, 08 Nov 2024   Prob (F-statistic):          6.53e-128
# Time:                        01:11:07   Log-Likelihood:                -125.30
# No. Observations:                 272   AIC:                             256.6
# Df Residuals:                     269   BIC:                             267.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6735      0.228      2.958      0.003       0.225       1.122
# ...

# %% [markdown]
# ###  Differences:
# Interaction Between Variables:
#
# The previous models separated the data based on different thresholds for short and long wait times, fitting separate linear models.
# The new model combines both subsets into a single model using an indicator variable to test if there is a significant difference in eruption duration between these two groups after adjusting for waiting time.
#
# The new model is simpler because it includes both short and long wait times in a unified framework.
# It allows us to directly test if there is a significant difference between the two groups, without the need to split the dataset and fit separate models.
#
# ### evidence against the null
#  Null Hypothesis: 𝛽 2 = 0, meaning no difference in eruption duration between short and long wait times after accounting for waiting time. Alternative Hypothesis: 𝛽 2 ≠ 0 , meaning there is a difference in eruption duration between short and long wait times.

# %% [markdown]
# # Question 12

# %%
import seaborn as sns
import statsmodels.formula.api as smf
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from scipy import stats
import numpy as np

# Load the Old Faithful dataset
old_faithful = sns.load_dataset('geyser')

# Define short and long wait times based on the new criteria
short_wait = old_faithful['waiting'] < 68
long_wait = old_faithful['waiting'] >= 68

# Residuals from the four models
model_residuals = {
    '<br>Model 1:<br>All Data using slope': smf.ols('duration ~ waiting', data=old_faithful).fit().resid,
    '<br>Model 2:<br>Short Wait Data': smf.ols('duration ~ waiting', data=old_faithful[short_wait]).fit().resid,
    '<br>Model 3:<br>Long Wait Data': smf.ols('duration ~ waiting', data=old_faithful[long_wait]).fit().resid,
    '<br>Model 4:<br>All Data using indicator': smf.ols('duration ~ C(kind, Treatment(reference="short"))', data=old_faithful).fit().resid
}

# Create subplots for residual histograms
fig = make_subplots(rows=2, cols=2, subplot_titles=list(model_residuals.keys()))

# Plot histograms with normal distribution overlay
for i, (title, resid) in enumerate(model_residuals.items()):
    # Define bin size based on the model
    bin_size = dict(start=-1.95, end=1.95, size=0.3)
    
    # Add histogram trace
    fig.add_trace(go.Histogram(x=resid, name=title, xbins=bin_size, histnorm='probability density'), 
                  row=int(i/2)+1, col=(i%2)+1)
    
    # Annotate number of residuals
    fig.update_xaxes(title_text="n="+str(len(resid)), row=int(i/2)+1, col=(i%2)+1)
    
    # Add normal distribution curve
    normal_range = np.arange(-3*resid.std(), 3*resid.std(), 0.01)
    fig.add_trace(go.Scatter(x=normal_range, 
                             y=stats.norm(loc=0, scale=resid.std()).pdf(normal_range),
                             mode='lines', opacity=0.5,
                             line=dict(color='black', dash='dot', width=2),
                             name='Normal Distribution<br>(99.7% of its area)'), 
                  row=int(i/2)+1, col=(i%2)+1)

# Update layout for better readability
fig.update_layout(title_text='Histograms of Residuals from Different Models')
fig.update_xaxes(range=[-2, 2])
fig.show(renderer="png")

fig.show(renderer="png") # USE `fig.show(renderer="png")` FOR ALL GitHub and MarkUs SUBMISSIONS

# %% [markdown]
# Most Likely to Support Normality:
# Model 4 is likely to support the normality assumption better. By including an indicator for short and long wait times, this model accounts for different variance structures and allows better capturing of the variability in the data. If its histogram is close to the normal distribution curve, it indicates that the errors are more normally distributed when this distinction is considered.

# %% [markdown]
# # Question 13
# # 13A)

# %%
import numpy as np

# Define observed mean difference
observed_diff = old_faithful[short_wait]['duration'].mean() - old_faithful[long_wait]['duration'].mean()

# Number of permutations
n_permutations = 10000
permuted_diffs = []

# Combine data and perform permutation
combined_data = old_faithful['duration'].values
labels = np.concatenate([np.ones(len(old_faithful[short_wait])), np.zeros(len(old_faithful[long_wait]))])

for _ in range(n_permutations):
    # Shuffle the labels
    np.random.shuffle(labels)
    short_sample = combined_data[labels == 1]
    long_sample = combined_data[labels == 0]
    
    # Compute mean difference
    permuted_diff = np.mean(short_sample) - np.mean(long_sample)
    permuted_diffs.append(permuted_diff)

# Calculate p-value
p_value = np.mean(np.abs(permuted_diffs) >= np.abs(observed_diff))
print(f"Observed Mean Difference: {observed_diff:.4f}")
print(f"Permutation Test p-value: {p_value:.4f}")
# Out:
# Observed Mean Difference: -2.2036
# Permutation Test p-value: 0.0000

# %% [markdown]
# # 13 B)

# %%
n_bootstrap = 10000
bootstrapped_mean_differences = []

for _ in range(n_bootstrap):
    short_sample = np.random.choice(old_faithful[short_wait]['duration'], size=len(old_faithful[short_wait]), replace=True)
    long_sample = np.random.choice(old_faithful[long_wait]['duration'], size=len(old_faithful[long_wait]), replace=True)
    
    # Calculate mean difference
    boot_mean_diff = np.mean(short_sample) - np.mean(long_sample)
    bootstrapped_mean_differences.append(boot_mean_diff)

# Calculate 95% CI
confidence_interval = np.quantile(bootstrapped_mean_differences, [0.025, 0.975])
print(f"95% Bootstrap Confidence Interval for Difference in Means: {confidence_interval}")
# Out:
# 95% Bootstrap Confidence Interval for Difference in Means: [-2.30098953 -2.10225599]

# %% [markdown]
# # 13a)
# By shuffling the labels, we create datasets that are consistent with the null hypothesis of no difference between the groups.
# It doesn't rely on assumptions about the distribution of data (e.g., normality).
# The test evaluates how likely the observed difference would be if the group labels were purely random.

# %% [markdown]
# # 13b)
# Overall, the indicator variable model provides an inferential approach using linear regression, while the permutation test and bootstrap method provide non-parametric ways to assess the difference in means. The bootstrap method provides an estimate of uncertainty, and the permutation test gives a direct hypothesis test, both free from the parametric assumptions of the indicator model.

# %% [markdown]
# # Question 14
# yes

# %% [markdown]
# # CHATGPT LINK: https://chatgpt.com/share/672d82a9-5058-8003-9c09-0d8db6094bf6
